# %% [markdown]
# # Cell Factory test

# %%
from pathfinder import Pathfinder

# abs_paths = ['']
# relative_paths = Pathfinder.relative_paths_from_abs(abs_paths)

relative_paths = [['..', '..', '..', '..', '..', '..', '已完成', 'Bridges', 'bitbucket', 'github', 'codes'],
                  ['..', '..', '..', '..', '..', 'Signal Generators', 'bitbucket', 'github', 'codes'],
                  ['..', '..', '..', '..', '..', 'Utilities', 'bitbucket', 'github', 'codes'],
                  ['..', '..', 'codes']]

Pathfinder.append_relative_paths(relative_paths)

# %%
import pandas as pd

#https://thispointer.com/python-pandas-how-to-display-full-dataframe-i-e-print-all-rows-columns-without-truncation/
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)

# %%
from bridges.ftdi.adapters.micropython import machine
from bridges.ftdi.controllers.i2c import I2cController
from sigma.sigma_dsp.adau import ADAU1401
from utilities.adapters import peripherals

# %% [markdown]
# ## Debug mode?

# %%
cls = ADAU1401

cls.DEBUG_MODE_SHOW_BUS_DATA = False         # whether to show bus data. 
cls.DEBUG_MODE_PRINT_REGISTER = False        # whether to print registers.

# %% [markdown]
# ## DSP processor

# %%
with_hardware_device = False  # set True if hardware is connected.

if with_hardware_device:
    
    ctrl = I2cController()
    _machine = ctrl.get_gpio()

    _i2c = ctrl.I2C()

    _pin_reset = _machine.Pin('ADBUS4', mode = machine.Pin.OUT)
    _pin_reset.high()

else:
    _i2c = _pin_reset = None  # using None for testing without actual hardware device.

bus = peripherals.I2C(_i2c)
# Out:
# ****** Virtual device. Data may not be real ! ******

# %%
# bus = fx2lp.I2C(as_400KHz = False)

# %%
dsp = ADAU1401(bus, pin_reset = _pin_reset)

# %% [markdown]
# ## Factory

# %%
import os
from sigma.factory import Factory 

project_xml_file_url = os.sep.join(['..', '..', 'SigmaStudio projects', 'projects', 'demo', 'demo.xml'])
class_files_root_url = os.sep.join(['..', '..', 'codes', 'sigma', 'sigma_studio', 'toolbox', 'cells']) 

factory = Factory(project_xml_file_url = project_xml_file_url,
                  class_files_root_url = class_files_root_url,
                  dsp = dsp
                 )

# %% [markdown]
# ## IC

# %%
ic = factory.get_ic()
ic.df
# Out:
#                                                                   param_full_name  \
# algorithm_name       cell_name            param_name
# FIRFiltAlg           FIR0                 fircoeff_0        FIRFiltAlg1fircoeff_0
#                      FIR1                 fircoeff_0        FIRFiltAlg2fircoeff_0
#                      FIR2                 fircoeff_0        FIRFiltAlg3fircoeff_0
#                      FIR3                 fircoeff_0        FIRFiltAlg4fircoeff_0
# Gain1940AlgNS        Gain_in0                                      Gain1940AlgNS3
#                      Gain_in1                                      Gain1940AlgNS2
#                      Gain_in2                                      Gain1940AlgNS7
#                      Gain_in3                                      Gain1940AlgNS8
#                      Gain_out0                                     Gain1940AlgNS1
#                      Gain_out1                                     Gain1940AlgNS4
#                      Gain_out2                                     Gain1940AlgNS5
#                      Gain_out3                                     Gain1940AlgNS6
# MonoNoPostGain3dBFix Compressor0                            MonoNoPostGain3dBFix1
#                                           RMS            MonoNoPostGain3dBFix1RMS
#                                           decay        MonoNoPostGain3dBFix1decay
#                                           hold          MonoNoPostGain3dBFix1hold
#                                           level        MonoNoPostGain3dBFix1level
#                      Compressor1                            MonoNoPostGain3dBFix2
#                                           RMS            MonoNoPostGain3dBFix2RMS
#                                           decay        MonoNoPostGain3dBFix2decay
#                                           hold          MonoNoPostGain3dBFix2hold
#                                           level        MonoNoPostGain3dBFix2level
#                      Compressor2                            MonoNoPostGain3dBFix3
#                                           RMS            MonoNoPostGain3dBFix3RMS
#                                           decay        MonoNoPostGain3dBFix3decay
#                                           hold          MonoNoPostGain3dBFix3hold
#                                           level        MonoNoPostGain3dBFix3level
#                      Compressor3                            MonoNoPostGain3dBFix4
#                                           RMS            MonoNoPostGain3dBFix4RMS
#                                           decay        MonoNoPostGain3dBFix4decay
#                                           hold          MonoNoPostGain3dBFix4hold
#                                           level        MonoNoPostGain3dBFix4level
# MultCtrlDelGrowAlg   Delay0                                   MultCtrlDelGrowAlg1
#                      Delay1                                   MultCtrlDelGrowAlg2
#                      Delay2                                   MultCtrlDelGrowAlg3
#                      Delay3                                   MultCtrlDelGrowAlg4
# MuteNoSlewAlg        Mute000              mute                 MuteNoSlewAlg1mute
#                      Mute001              mute                 MuteNoSlewAlg4mute
#                      Mute002              mute                 MuteNoSlewAlg7mute
#                      Mute003              mute                MuteNoSlewAlg10mute
#                      Mute010              mute                 MuteNoSlewAlg2mute
#                      Mute011              mute                 MuteNoSlewAlg6mute
#                      Mute012              mute                 MuteNoSlewAlg9mute
#                      Mute013              mute                MuteNoSlewAlg12mute
#                      Mute100              mute                MuteNoSlewAlg17mute
#                      Mute101              mute                MuteNoSlewAlg19mute
#                      Mute102              mute                MuteNoSlewAlg21mute
#                      Mute103              mute                MuteNoSlewAlg23mute
#                      Mute110              mute                MuteNoSlewAlg18mute
#                      Mute111              mute                MuteNoSlewAlg20mute
#                      Mute112              mute                MuteNoSlewAlg22mute
#                      Mute113              mute                MuteNoSlewAlg24mute
#                      Mute_in0             mute                MuteNoSlewAlg13mute
#                      Mute_in1             mute                MuteNoSlewAlg14mute
#                      Mute_in2             mute                MuteNoSlewAlg15mute
#                      Mute_in3             mute                MuteNoSlewAlg16mute
#                      Mute_out0            mute                 MuteNoSlewAlg3mute
#                      Mute_out1            mute                 MuteNoSlewAlg5mute
#                      Mute_out2            mute                 MuteNoSlewAlg8mute
#                      Mute_out3            mute                MuteNoSlewAlg11mute
# PEQ1Chan             Param EQ_in0         0B1                        PEQ1Chan10B1
#                                           1A1                        PEQ1Chan11A1
#                                           1B1                        PEQ1Chan11B1
#                                           2A1                        PEQ1Chan12A1
#                                           2B1                        PEQ1Chan12B1
#                      Param EQ_in1         0B1                        PEQ1Chan30B1
#                                           1A1                        PEQ1Chan31A1
#                                           1B1                        PEQ1Chan31B1
#                                           2A1                        PEQ1Chan32A1
#                                           2B1                        PEQ1Chan32B1
#                      Param EQ_in2         0B1                        PEQ1Chan70B1
#                                           1A1                        PEQ1Chan71A1
#                                           1B1                        PEQ1Chan71B1
#                                           2A1                        PEQ1Chan72A1
#                                           2B1                        PEQ1Chan72B1
#                      Param EQ_in3         0B1                        PEQ1Chan80B1
#                                           1A1                        PEQ1Chan81A1
#                                           1B1                        PEQ1Chan81B1
#                                           2A1                        PEQ1Chan82A1
#                                           2B1                        PEQ1Chan82B1
#                      Param EQ_out0        0B1                        PEQ1Chan20B1
#                                           1A1                        PEQ1Chan21A1
#                                           1B1                        PEQ1Chan21B1
#                                           2A1                        PEQ1Chan22A1
#                                           2B1                        PEQ1Chan22B1
#                      Param EQ_out1        0B1                        PEQ1Chan40B1
#                                           1A1                        PEQ1Chan41A1
#                                           1B1                        PEQ1Chan41B1
#                                           2A1                        PEQ1Chan42A1
#                                           2B1                        PEQ1Chan42B1
#                      Param EQ_out2        0B1                        PEQ1Chan50B1
#                                           1A1                        PEQ1Chan51A1
#                                           1B1                        PEQ1Chan51B1
#                                           2A1                        PEQ1Chan52A1
#                                           2B1                        PEQ1Chan52B1
#                      Param EQ_out3        0B1                        PEQ1Chan60B1
#                                           1A1                        PEQ1Chan61A1
#                                           1B1                        PEQ1Chan61B1
#                                           2A1                        PEQ1Chan62A1
#                                           2B1                        PEQ1Chan62B1
# SWGain1940DBAlg      Volume_Control_in0   step               SWGain1940DBAlg1step
#                                           target           SWGain1940DBAlg1target
#                      Volume_Control_in1   step               SWGain1940DBAlg4step
#                                           target           SWGain1940DBAlg4target
#                      Volume_Control_out01 step               SWGain1940DBAlg2step
#                                           target           SWGain1940DBAlg2target
#                      Volume_Control_out23 step               SWGain1940DBAlg3step
#                                           target           SWGain1940DBAlg3target
# SingleCtrlMixer      Merger0                                 SingleCtrlMixer19401
#                      Merger1                                 SingleCtrlMixer19402
#                      Merger2                                 SingleCtrlMixer19403
#                      Merger3                                 SingleCtrlMixer19404
# StMuxSwSlew          Source_Switch_0      coeffname         StMuxSwSlew1coeffname
#                      Source_Switch_1      coeffname         StMuxSwSlew2coeffname
# WhiteNAlgNew         White_Noise          enable              WhiteNAlgNew1enable
#                                           mxx                    WhiteNAlgNew1mxx
# sin_lookupAlg        Tone1                increment   sin_lookupAlg19401increment
#                                           ison             sin_lookupAlg19401ison
#                                           mask             sin_lookupAlg19401mask
#                      Tone2                increment   sin_lookupAlg19402increment
#                                           ison             sin_lookupAlg19402ison
#                                           mask             sin_lookupAlg19402mask
#
#                                                        type          value  \
# algorithm_name       cell_name            param_name
# FIRFiltAlg           FIR0                 fircoeff_0  bytes            NaN
#                      FIR1                 fircoeff_0  bytes            NaN
#                      FIR2                 fircoeff_0  bytes            NaN
#                      FIR3                 fircoeff_0  bytes            NaN
# Gain1940AlgNS        Gain_in0                         float       1.000000
#                      Gain_in1                         float       1.000000
#                      Gain_in2                         float       1.000000
#                      Gain_in3                         float       1.000000
#                      Gain_out0                        float       1.000000
#                      Gain_out1                        float       1.000000
#                      Gain_out2                        float       1.000000
#                      Gain_out3                        float       1.000000
# MonoNoPostGain3dBFix Compressor0                      bytes            NaN
#                                           RMS         float       0.000581
#                                           decay       float       0.000002
#                                           hold        float       0.000000
#                                           level       float       0.002500
#                      Compressor1                      bytes            NaN
#                                           RMS         float       0.000581
#                                           decay       float       0.000002
#                                           hold        float       0.000000
#                                           level       float       0.002500
#                      Compressor2                      bytes            NaN
#                                           RMS         float       0.000581
#                                           decay       float       0.000002
#                                           hold        float       0.000000
#                                           level       float       0.002500
#                      Compressor3                      bytes            NaN
#                                           RMS         float       0.000581
#                                           decay       float       0.000002
#                                           hold        float       0.000000
#                                           level       float       0.002500
# MultCtrlDelGrowAlg   Delay0                             int       1.000000
#                      Delay1                             int       1.000000
#                      Delay2                             int       1.000000
#                      Delay3                             int       1.000000
# MuteNoSlewAlg        Mute000              mute        float       1.000000
#                      Mute001              mute        float       0.000000
#                      Mute002              mute        float       0.000000
#                      Mute003              mute        float       0.000000
#                      Mute010              mute        float       0.000000
#                      Mute011              mute        float       1.000000
#                      Mute012              mute        float       0.000000
#                      Mute013              mute        float       0.000000
#                      Mute100              mute        float       0.000000
#                      Mute101              mute        float       0.000000
#                      Mute102              mute        float       1.000000
#                      Mute103              mute        float       0.000000
#                      Mute110              mute        float       0.000000
#                      Mute111              mute        float       0.000000
#                      Mute112              mute        float       0.000000
#                      Mute113              mute        float       1.000000
#                      Mute_in0             mute        float       1.000000
#                      Mute_in1             mute        float       1.000000
#                      Mute_in2             mute        float       1.000000
#                      Mute_in3             mute        float       1.000000
#                      Mute_out0            mute        float       1.000000
#                      Mute_out1            mute        float       1.000000
#                      Mute_out2            mute        float       1.000000
#                      Mute_out3            mute        float       1.000000
# PEQ1Chan             Param EQ_in0         0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_in1         0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_in2         0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_in3         0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_out0        0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_out1        0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_out2        0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
#                      Param EQ_out3        0B1         float       1.001689
#                                           1A1         float       1.995592
#                                           1B1         float      -1.995592
#                                           2A1         float      -0.995658
#                                           2B1         float       0.993969
# SWGain1940DBAlg      Volume_Control_in0   step        float       0.000244
#                                           target      float       1.000000
#                      Volume_Control_in1   step        float       0.000244
#                                           target      float       1.000000
#                      Volume_Control_out01 step        float       0.000244
#                                           target      float       0.173780
#                      Volume_Control_out23 step        float       0.000244
#                                           target      float       0.158489
# SingleCtrlMixer      Merger0                          float       0.250000
#                      Merger1                          float       0.250000
#                      Merger2                          float       0.250000
#                      Merger3                          float       0.250000
# StMuxSwSlew          Source_Switch_0      coeffname   float       0.000000
#                      Source_Switch_1      coeffname     int       2.000000
# WhiteNAlgNew         White_Noise          enable      float       1.000000
#                                           mxx           int  345675.000000
# sin_lookupAlg        Tone1                increment   float       0.004583
#                                           ison        float       1.000000
#                                           mask          int     255.000000
#                      Tone2                increment   float       0.004750
#                                           ison        float       1.000000
#                                           mask          int     255.000000
#
#                                                       address  n_bytes
# algorithm_name       cell_name            param_name
# FIRFiltAlg           FIR0                 fircoeff_0       82       40
#                      FIR1                 fircoeff_0       92       40
#                      FIR2                 fircoeff_0      102       40
#                      FIR3                 fircoeff_0      112       40
# Gain1940AlgNS        Gain_in0                              38        4
#                      Gain_in1                              39        4
#                      Gain_in2                              41        4
#                      Gain_in3                              40        4
#                      Gain_out0                            126        4
#                      Gain_out1                            127        4
#                      Gain_out2                            128        4
#                      Gain_out3                            129        4
# MonoNoPostGain3dBFix Compressor0                          134      160
#                                           RMS             174        4
#                                           decay           176        4
#                                           hold            175        4
#                                           level           177        4
#                      Compressor1                          178      160
#                                           RMS             218        4
#                                           decay           220        4
#                                           hold            219        4
#                                           level           221        4
#                      Compressor2                          266      160
#                                           RMS             306        4
#                                           decay           308        4
#                                           hold            307        4
#                                           level           309        4
#                      Compressor3                          222      160
#                                           RMS             262        4
#                                           decay           264        4
#                                           hold            263        4
#                                           level           265        4
# MultCtrlDelGrowAlg   Delay0                               122        4
#                      Delay1                               123        4
#                      Delay2                               124        4
#                      Delay3                               125        4
# MuteNoSlewAlg        Mute000              mute             42        4
#                      Mute001              mute             44        4
#                      Mute002              mute             45        4
#                      Mute003              mute             46        4
#                      Mute010              mute             43        4
#                      Mute011              mute             47        4
#                      Mute012              mute             48        4
#                      Mute013              mute             49        4
#                      Mute100              mute             50        4
#                      Mute101              mute             52        4
#                      Mute102              mute             54        4
#                      Mute103              mute             56        4
#                      Mute110              mute             51        4
#                      Mute111              mute             53        4
#                      Mute112              mute             55        4
#                      Mute113              mute             57        4
#                      Mute_in0             mute             14        4
#                      Mute_in1             mute             15        4
#                      Mute_in2             mute             16        4
#                      Mute_in3             mute             17        4
#                      Mute_out0            mute            310        4
#                      Mute_out1            mute            311        4
#                      Mute_out2            mute            312        4
#                      Mute_out3            mute            313        4
# PEQ1Chan             Param EQ_in0         0B1              18        4
#                                           1A1              21        4
#                                           1B1              19        4
#                                           2A1              22        4
#                                           2B1              20        4
#                      Param EQ_in1         0B1              23        4
#                                           1A1              26        4
#                                           1B1              24        4
#                                           2A1              27        4
#                                           2B1              25        4
#                      Param EQ_in2         0B1              28        4
#                                           1A1              31        4
#                                           1B1              29        4
#                                           2A1              32        4
#                                           2B1              30        4
#                      Param EQ_in3         0B1              33        4
#                                           1A1              36        4
#                                           1B1              34        4
#                                           2A1              37        4
#                                           2B1              35        4
#                      Param EQ_out0        0B1              62        4
#                                           1A1              65        4
#                                           1B1              63        4
#                                           2A1              66        4
#                                           2B1              64        4
#                      Param EQ_out1        0B1              67        4
#                                           1A1              70        4
#                                           1B1              68        4
#                                           2A1              71        4
#                                           2B1              69        4
#                      Param EQ_out2        0B1              72        4
#                                           1A1              75        4
#                                           1B1              73        4
#                                           2A1              76        4
#                                           2B1              74        4
#                      Param EQ_out3        0B1              77        4
#                                           1A1              80        4
#                                           1B1              78        4
#                                           2A1              81        4
#                                           2B1              79        4
# SWGain1940DBAlg      Volume_Control_in0   step             11        4
#                                           target           10        4
#                      Volume_Control_in1   step             13        4
#                                           target           12        4
#                      Volume_Control_out01 step            131        4
#                                           target          130        4
#                      Volume_Control_out23 step            133        4
#                                           target          132        4
# SingleCtrlMixer      Merger0                               58        4
#                      Merger1                               59        4
#                      Merger2                               60        4
#                      Merger3                               61        4
# StMuxSwSlew          Source_Switch_0      coeffname         8        4
#                      Source_Switch_1      coeffname         9        4
# WhiteNAlgNew         White_Noise          enable            6        4
#                                           mxx               7        4
# sin_lookupAlg        Tone1                increment         1        4
#                                           ison              2        4
#                                           mask              0        4
#                      Tone2                increment         4        4
#                                           ison              5        4
#                                           mask              3        4

# %% [markdown]
# ## Cells

# %%
cells = factory.get_cells()
# cells.keys()

# %% [markdown]
# ## Cell's methods / properties description

# %%
factory.show_methods()
# Out:
# {
#     "Tone1": {
#         "cell_name": "Tone1",
#         "algorithm_name": "sin_lookupAlg",
#         "methods": [
#             "enable(value=True, param_name=None, send_now=True, **kwargs)",
#             "get_frequency(param_name=None, freq_ratio=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_frequency(frequency, param_name=None, freq_ratio=None, mask=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "FREQ_MASK",
#             "FREQ_PARAM",
#             "FREQ_RATIO",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Tone2": {
#         "cell_name": "Tone2",
#         "algorithm_name": "sin_lookupAlg",
#         "methods": [
#             "enable(value=True, param_name=None, send_now=True, **kwargs)",
#             "get_frequency(param_name=None, freq_ratio=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_frequency(frequency, param_name=None, freq_ratio=None, mask=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "FREQ_MASK",
#             "FREQ_PARAM",
#             "FREQ_RATIO",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "White_Noise": {
#         "cell_name": "White_Noise",
#         "algorithm_name": "WhiteNAlgNew",
#         "methods": [
#             "enable(value=True, param_name=None, send_now=True, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "FREQ_MASK",
#             "FREQ_PARAM",
#             "FREQ_RATIO",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Source_Switch_0": {
#         "cell_name": "Source_Switch_0",
#         "algorithm_name": "StMuxSwSlew",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "switch(idx_on, **kwargs)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "SWITCH_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "FIR0": {
#         "cell_name": "FIR0",
#         "algorithm_name": "FIRFiltAlg",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(coefficients, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_out0": {
#         "cell_name": "Gain_out0",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute000": {
#         "cell_name": "Mute000",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_in0": {
#         "cell_name": "Gain_in0",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_out0": {
#         "cell_name": "Mute_out0",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_in0": {
#         "cell_name": "Param EQ_in0",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Merger0": {
#         "cell_name": "Merger0",
#         "algorithm_name": "SingleCtrlMixer",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Delay0": {
#         "cell_name": "Delay0",
#         "algorithm_name": "MultCtrlDelGrowAlg",
#         "methods": [
#             "get_delayed_ms(**kwargs)",
#             "get_delayed_samples(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_delayed_ms(delayed_ms=0, **kwargs)",
#             "set_delayed_samples(n=0, **kwargs)",
#             "set_max_buffer_size(n=1, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "BUFFERSIZE_PARAM",
#             "DELAY_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_out0": {
#         "cell_name": "Param EQ_out0",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute010": {
#         "cell_name": "Mute010",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_in1": {
#         "cell_name": "Gain_in1",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_in1": {
#         "cell_name": "Param EQ_in1",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Compressor0": {
#         "cell_name": "Compressor0",
#         "algorithm_name": "MonoNoPostGain3dBFix",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_decay(dB_s, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_hold_time(time_ms, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_rms_tc(dB_s, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "DECAY_PARAM",
#             "GAIN_PARAM",
#             "HOLD_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "RMS_PARAM",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "FIR1": {
#         "cell_name": "FIR1",
#         "algorithm_name": "FIRFiltAlg",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(coefficients, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_out1": {
#         "cell_name": "Gain_out1",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute001": {
#         "cell_name": "Mute001",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_out1": {
#         "cell_name": "Mute_out1",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Merger1": {
#         "cell_name": "Merger1",
#         "algorithm_name": "SingleCtrlMixer",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Delay1": {
#         "cell_name": "Delay1",
#         "algorithm_name": "MultCtrlDelGrowAlg",
#         "methods": [
#             "get_delayed_ms(**kwargs)",
#             "get_delayed_samples(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_delayed_ms(delayed_ms=0, **kwargs)",
#             "set_delayed_samples(n=0, **kwargs)",
#             "set_max_buffer_size(n=1, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "BUFFERSIZE_PARAM",
#             "DELAY_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_out1": {
#         "cell_name": "Param EQ_out1",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute011": {
#         "cell_name": "Mute011",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Compressor1": {
#         "cell_name": "Compressor1",
#         "algorithm_name": "MonoNoPostGain3dBFix",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_decay(dB_s, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_hold_time(time_ms, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_rms_tc(dB_s, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "DECAY_PARAM",
#             "GAIN_PARAM",
#             "HOLD_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "RMS_PARAM",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "FIR2": {
#         "cell_name": "FIR2",
#         "algorithm_name": "FIRFiltAlg",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(coefficients, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_out2": {
#         "cell_name": "Gain_out2",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute002": {
#         "cell_name": "Mute002",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_out2": {
#         "cell_name": "Mute_out2",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Merger2": {
#         "cell_name": "Merger2",
#         "algorithm_name": "SingleCtrlMixer",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Delay2": {
#         "cell_name": "Delay2",
#         "algorithm_name": "MultCtrlDelGrowAlg",
#         "methods": [
#             "get_delayed_ms(**kwargs)",
#             "get_delayed_samples(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_delayed_ms(delayed_ms=0, **kwargs)",
#             "set_delayed_samples(n=0, **kwargs)",
#             "set_max_buffer_size(n=1, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "BUFFERSIZE_PARAM",
#             "DELAY_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_out2": {
#         "cell_name": "Param EQ_out2",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute012": {
#         "cell_name": "Mute012",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Compressor2": {
#         "cell_name": "Compressor2",
#         "algorithm_name": "MonoNoPostGain3dBFix",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_decay(dB_s, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_hold_time(time_ms, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_rms_tc(dB_s, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "DECAY_PARAM",
#             "GAIN_PARAM",
#             "HOLD_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "RMS_PARAM",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "FIR3": {
#         "cell_name": "FIR3",
#         "algorithm_name": "FIRFiltAlg",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(coefficients, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_out3": {
#         "cell_name": "Gain_out3",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute003": {
#         "cell_name": "Mute003",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_out3": {
#         "cell_name": "Mute_out3",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Merger3": {
#         "cell_name": "Merger3",
#         "algorithm_name": "SingleCtrlMixer",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Delay3": {
#         "cell_name": "Delay3",
#         "algorithm_name": "MultCtrlDelGrowAlg",
#         "methods": [
#             "get_delayed_ms(**kwargs)",
#             "get_delayed_samples(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_delayed_ms(delayed_ms=0, **kwargs)",
#             "set_delayed_samples(n=0, **kwargs)",
#             "set_max_buffer_size(n=1, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "BUFFERSIZE_PARAM",
#             "DELAY_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_out3": {
#         "cell_name": "Param EQ_out3",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute013": {
#         "cell_name": "Mute013",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Compressor3": {
#         "cell_name": "Compressor3",
#         "algorithm_name": "MonoNoPostGain3dBFix",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "get_table(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_decay(dB_s, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_hold_time(time_ms, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_rms_tc(dB_s, **kwargs)",
#             "set_table(values, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "DECAY_PARAM",
#             "GAIN_PARAM",
#             "HOLD_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "RMS_PARAM",
#             "TABLE_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_in0": {
#         "cell_name": "Mute_in0",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_in1": {
#         "cell_name": "Mute_in1",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Volume_Control_in0": {
#         "cell_name": "Volume_Control_in0",
#         "algorithm_name": "SWGain1940DBAlg",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_slew_rate(slew_rate, **kwargs)",
#             "set_volume(dB, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "SLEW_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties",
#             "slew_rate"
#         ]
#     },
#     "Volume_Control_out01": {
#         "cell_name": "Volume_Control_out01",
#         "algorithm_name": "SWGain1940DBAlg",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_slew_rate(slew_rate, **kwargs)",
#             "set_volume(dB, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "SLEW_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties",
#             "slew_rate"
#         ]
#     },
#     "Volume_Control_out23": {
#         "cell_name": "Volume_Control_out23",
#         "algorithm_name": "SWGain1940DBAlg",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_slew_rate(slew_rate, **kwargs)",
#             "set_volume(dB, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "SLEW_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties",
#             "slew_rate"
#         ]
#     },
#     "Source_Switch_1": {
#         "cell_name": "Source_Switch_1",
#         "algorithm_name": "StMuxSwSlew",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "switch(idx_on, **kwargs)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "SWITCH_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_in2": {
#         "cell_name": "Gain_in2",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_in2": {
#         "cell_name": "Param EQ_in2",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Gain_in3": {
#         "cell_name": "Gain_in3",
#         "algorithm_name": "Gain1940AlgNS",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Param EQ_in3": {
#         "cell_name": "Param EQ_in3",
#         "algorithm_name": "PEQ1Chan",
#         "methods": [
#             "get_coefficients(**kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_coefficients(label_value_pairs, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_in2": {
#         "cell_name": "Mute_in2",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute_in3": {
#         "cell_name": "Mute_in3",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Volume_Control_in1": {
#         "cell_name": "Volume_Control_in1",
#         "algorithm_name": "SWGain1940DBAlg",
#         "methods": [
#             "dB_to_gain(dB)",
#             "gain_to_dB(gain)",
#             "get_dB(param_name=None, **kwargs)",
#             "get_gain(param_name=None, **kwargs)",
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "read_parameter(param)",
#             "set_dB(dB, param_name=None, **kwargs)",
#             "set_gain(gain, param_name=None, **kwargs)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "set_slew_rate(slew_rate, **kwargs)",
#             "set_volume(dB, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "GAIN_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "SLEW_PARAM",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties",
#             "slew_rate"
#         ]
#     },
#     "Mute100": {
#         "cell_name": "Mute100",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute110": {
#         "cell_name": "Mute110",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute101": {
#         "cell_name": "Mute101",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute111": {
#         "cell_name": "Mute111",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute102": {
#         "cell_name": "Mute102",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute112": {
#         "cell_name": "Mute112",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute103": {
#         "cell_name": "Mute103",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     },
#     "Mute113": {
#         "cell_name": "Mute113",
#         "algorithm_name": "MuteNoSlewAlg",
#         "methods": [
#             "get_param(param_name='', algorithm_idx=0)",
#             "get_parameters_values(**kwargs)",
#             "mute(value=True, **kwargs)",
#             "read_parameter(param)",
#             "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#             "set_parameters_values(name_value_pairs, **kwargs)",
#             "show_methods(print_out=True)",
#             "write_parameter(param, send_now=True)"
#         ],
#         "properties": [
#             "ENABLE_PARAM",
#             "PARAMETER_SHORT_NAMES",
#             "algorithm_name",
#             "description",
#             "df",
#             "name",
#             "parameters",
#             "properties"
#         ]
#     }
# }

# %% [markdown]
# ## Cell's operations

# %%
# for o in factory.get_cells_manifest():
#     print(o)

# %%
compressor0 = cells['Compressor0']  # Mono RMS Full Range (No Post Gain)( 1 )
compressor1 = cells['Compressor1']  # Mono RMS Full Range (No Post Gain)( 1 )
compressor2 = cells['Compressor2']  # Mono RMS Full Range (No Post Gain)( 1 )
compressor3 = cells['Compressor3']  # Mono RMS Full Range (No Post Gain)( 1 )
delay0 = cells['Delay0']  # Del_Grow( 1 )
delay1 = cells['Delay1']  # Del_Grow( 1 )
delay2 = cells['Delay2']  # Del_Grow( 1 )
delay3 = cells['Delay3']  # Del_Grow( 1 )
fir0 = cells['FIR0']  # FIR( 1 )
fir1 = cells['FIR1']  # FIR( 1 )
fir2 = cells['FIR2']  # FIR( 1 )
fir3 = cells['FIR3']  # FIR( 1 )
gain_in0 = cells['Gain_in0']  # Gain (no slew)( 1 )
gain_in1 = cells['Gain_in1']  # Gain (no slew)( 1 )
gain_in2 = cells['Gain_in2']  # Gain (no slew)( 1 )
gain_in3 = cells['Gain_in3']  # Gain (no slew)( 1 )
gain_out0 = cells['Gain_out0']  # Gain (no slew)( 1 )
gain_out1 = cells['Gain_out1']  # Gain (no slew)( 1 )
gain_out2 = cells['Gain_out2']  # Gain (no slew)( 1 )
gain_out3 = cells['Gain_out3']  # Gain (no slew)( 1 )
merger0 = cells['Merger0']  # Signal MixerC
merger1 = cells['Merger1']  # Signal MixerC
merger2 = cells['Merger2']  # Signal MixerC
merger3 = cells['Merger3']  # Signal MixerC
mute000 = cells['Mute000']  # No Slew (Standard)( 1 )
mute001 = cells['Mute001']  # No Slew (Standard)( 1 )
mute002 = cells['Mute002']  # No Slew (Standard)( 1 )
mute003 = cells['Mute003']  # No Slew (Standard)( 1 )
mute010 = cells['Mute010']  # No Slew (Standard)( 1 )
mute011 = cells['Mute011']  # No Slew (Standard)( 1 )
mute012 = cells['Mute012']  # No Slew (Standard)( 1 )
mute013 = cells['Mute013']  # No Slew (Standard)( 1 )
mute100 = cells['Mute100']  # No Slew (Standard)( 1 )
mute101 = cells['Mute101']  # No Slew (Standard)( 1 )
mute102 = cells['Mute102']  # No Slew (Standard)( 1 )
mute103 = cells['Mute103']  # No Slew (Standard)( 1 )
mute110 = cells['Mute110']  # No Slew (Standard)( 1 )
mute111 = cells['Mute111']  # No Slew (Standard)( 1 )
mute112 = cells['Mute112']  # No Slew (Standard)( 1 )
mute113 = cells['Mute113']  # No Slew (Standard)( 1 )
mute_in0 = cells['Mute_in0']  # No Slew (Standard)( 1 )
mute_in1 = cells['Mute_in1']  # No Slew (Standard)( 1 )
mute_in2 = cells['Mute_in2']  # No Slew (Standard)( 1 )
mute_in3 = cells['Mute_in3']  # No Slew (Standard)( 1 )
mute_out0 = cells['Mute_out0']  # No Slew (Standard)( 1 )
mute_out1 = cells['Mute_out1']  # No Slew (Standard)( 1 )
mute_out2 = cells['Mute_out2']  # No Slew (Standard)( 1 )
mute_out3 = cells['Mute_out3']  # No Slew (Standard)( 1 )
param_eq_in0 = cells['Param EQ_in0']  # PEQ1Chan - Double Precision( 1 )
param_eq_in1 = cells['Param EQ_in1']  # PEQ1Chan - Double Precision( 1 )
param_eq_in2 = cells['Param EQ_in2']  # PEQ1Chan - Double Precision( 1 )
param_eq_in3 = cells['Param EQ_in3']  # PEQ1Chan - Double Precision( 1 )
param_eq_out0 = cells['Param EQ_out0']  # PEQ1Chan - Double Precision( 1 )
param_eq_out1 = cells['Param EQ_out1']  # PEQ1Chan - Double Precision( 1 )
param_eq_out2 = cells['Param EQ_out2']  # PEQ1Chan - Double Precision( 1 )
param_eq_out3 = cells['Param EQ_out3']  # PEQ1Chan - Double Precision( 1 )
source_switch_0 = cells['Source_Switch_0']  # Stereo SW Slew( 3 )
source_switch_1 = cells['Source_Switch_1']  # Stereo SW Slew( 3 )
tone1 = cells['Tone1']  # Tone Synthesis (lookup/sine)( 1 )
tone2 = cells['Tone2']  # Tone Synthesis (lookup/sine)( 1 )
volume_control_in0 = cells['Volume_Control_in0']  # Gain (RC Slew)( 1 )
volume_control_in1 = cells['Volume_Control_in1']  # Gain (RC Slew)( 1 )
volume_control_out01 = cells['Volume_Control_out01']  # Gain (RC Slew)( 1 )
volume_control_out23 = cells['Volume_Control_out23']  # Gain (RC Slew)( 1 )
white_noise = cells['White_Noise']  # White Noise( 1 )

# %%
len(param_eq_in3.properties)
# Out:
# 226

# %%
param_eq_in3.df
# Out:
#                                        param_full_name   type     value  \
# cell_name    algorithm_name param_name
# Param EQ_in3 PEQ1Chan       0B1           PEQ1Chan80B1  float  1.001689
#                             1A1           PEQ1Chan81A1  float  1.995592
#                             1B1           PEQ1Chan81B1  float -1.995592
#                             2A1           PEQ1Chan82A1  float -0.995658
#                             2B1           PEQ1Chan82B1  float  0.993969
#
#                                         address  n_bytes
# cell_name    algorithm_name param_name
# Param EQ_in3 PEQ1Chan       0B1              33        4
#                             1A1              36        4
#                             1B1              34        4
#                             2A1              37        4
#                             2B1              35        4

# %%
volume_control_in0.properties
# Out:
# {'Gain`max': 0, 'Gain`min': -80, 'Gain`res': 100, 'Gain': 0}

# %%
volume_control_in0.df
# Out:
#                                                       param_full_name   type  \
# cell_name          algorithm_name  param_name
# Volume_Control_in0 SWGain1940DBAlg step          SWGain1940DBAlg1step  float
#                                    target      SWGain1940DBAlg1target  float
#
#                                                   value  address  n_bytes
# cell_name          algorithm_name  param_name
# Volume_Control_in0 SWGain1940DBAlg step        0.000244       11        4
#                                    target      1.000000       10        4

# %%
tone1.algorithm_name
# Out:
# 'sin_lookupAlg'

# %%
tone1.description
# Out:
# 'Tone Synthesis (lookup/sine)( 1 )'

# %%
tone1.PARAMETER_SHORT_NAMES
# Out:
# ['increment', 'ison', 'mask']

# %%
tone1.df
# Out:
#                                                  param_full_name   type  \
# cell_name algorithm_name param_name
# Tone1     sin_lookupAlg  increment   sin_lookupAlg19401increment  float
#                          ison             sin_lookupAlg19401ison  float
#                          mask             sin_lookupAlg19401mask    int
#
#                                           value  address  n_bytes
# cell_name algorithm_name param_name
# Tone1     sin_lookupAlg  increment     0.004583        1        4
#                          ison          1.000000        2        4
#                          mask        255.000000        0        4

# %%
tone1.show_methods()
# Out:
# {
#     "cell_name": "Tone1",
#     "algorithm_name": "sin_lookupAlg",
#     "methods": [
#         "enable(value=True, param_name=None, send_now=True, **kwargs)",
#         "get_frequency(param_name=None, freq_ratio=None, **kwargs)",
#         "get_param(param_name='', algorithm_idx=0)",
#         "get_parameters_values(**kwargs)",
#         "read_parameter(param)",
#         "set_frequency(frequency, param_name=None, freq_ratio=None, mask=None, **kwargs)",
#         "set_param(data, param_name='', send_now=True, algorithm_idx=None)",
#         "set_parameters_values(name_value_pairs, **kwargs)",
#         "show_methods(print_out=True)",
#         "write_parameter(param, send_now=True)"
#     ],
#     "properties": [
#         "ENABLE_PARAM",
#         "FREQ_MASK",
#         "FREQ_PARAM",
#         "FREQ_RATIO",
#         "PARAMETER_SHORT_NAMES",
#         "algorithm_name",
#         "description",
#         "df",
#         "name",
#         "parameters",
#         "properties"
#     ]
# }

# %%
tone1.get_parameters_values()
# Out:
# [['increment', 0.00458335876464844], ['ison', 1.0], ['mask', 255]]

# %%
tone1.set_frequency(441)

# %%
tone1.get_frequency()
# Out:
# 441.0

# %% [markdown]
# ## Classes list and check

# %%
df, df_duplicated_classes, df_duplicated_files = factory.get_classes_df()

# %%
df_duplicated_classes
# Out:
#       class_name               file_name  \
# 92   LookUpTable        lookup_tables.py
# 93   LookUpTable                 cell.py
# 177          RMS  dynamics_processors.py
# 178          RMS                  rms.py
# 239       Switch       demultiplexers.py
# 240       Switch               switch.py
# 241       Switch         multiplexers.py
# 242       Switch                 cell.py
#
#                                                   path
# 92   ..\..\codes\sigma\sigma_studio\toolbox\cells\l...
# 93   ..\..\codes\sigma\sigma_studio\toolbox\cells\c...
# 177  ..\..\codes\sigma\sigma_studio\toolbox\cells\d...
# 178  ..\..\codes\sigma\sigma_studio\toolbox\cells\d...
# 239  ..\..\codes\sigma\sigma_studio\toolbox\cells\m...
# 240  ..\..\codes\sigma\sigma_studio\toolbox\cells\s...
# 241  ..\..\codes\sigma\sigma_studio\toolbox\cells\m...
# 242  ..\..\codes\sigma\sigma_studio\toolbox\cells\c...

# %%
df_duplicated_files
# Out:
# Empty DataFrame
# Columns: [file_name, path]
# Index: []
